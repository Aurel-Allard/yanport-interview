# %% [markdown]
# # Test technique Aurélien Allard

# %% [markdown]
# Ce test a pour but de regrouper les annonces disponibles sur [ce lien Google Sheet](https://docs.google.com/spreadsheets/d/1XUjqeXVgjZJ8jVNAn9MeIb9zHLhVj4mwRs-hk1P050o/edit).

# %% [markdown]
# ## Connexion à la table Google Sheet

# %% [markdown]
# Tout d'abord nous désirons importer l'ensemble des données sous un format exploitable par Pandas, afin de pouvoir les manipuler et analyser.
#
# Nous redéfinissons pour cela un extrait csv de la table en réécrivant son url.

# %%
import numpy as np
import pandas as pd

# Définition des variables
sheet_url = "https://docs.google.com/spreadsheets/d/1XUjqeXVgjZJ8jVNAn9MeIb9zHLhVj4mwRs-hk1P050o/edit#gid=1762609115"
csv_url = sheet_url.replace("/edit#gid=", "/export?format=csv&gid=")

# Extraction du csv dans un dataframe Pandas
raw_df = pd.read_csv(csv_url,
                   # Nous attribuons l'index  des lignes à la colonne ID
                   index_col=0,
                  )

# Visualisation du résultat
raw_df.head(2)
# Out:
#                                                                                     URL  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  http://www.avendrealouer.fr/location/levallois...
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d  https://www.bienici.com/annonce/ag440414-16547...
#
#                                           CRAWL_SOURCE PROPERTY_TYPE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  A_VENDRE_A_LOUER     APARTMENT
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d          BIEN_ICI     APARTMENT
#
#                                      NEW_BUILD  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe     False
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d     False
#
#                                                                             DESCRIPTION  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  Au rez de chaussée d'un bel immeuble récent,ap...
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d  Je vous propose un appartement dans la rue Col...
#
#                                                                                  IMAGES  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  ["https://cf-medias.avendrealouer.fr/image/_87...
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d  ["http://photos.ubiflow.net/440414/165474561/p...
#
#                                       SURFACE  LAND_SURFACE  BALCONY_SURFACE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe     72.0           NaN              NaN
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d     48.0           NaN              NaN
#
#                                       TERRACE_SURFACE  ...  \
# ID                                                     ...
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe              NaN  ...
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d              NaN  ...
#
#                                                DEALER_NAME  DEALER_TYPE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  Lamirand Et Associes       AGENCY
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d    Proprietes Privees    MANDATARY
#
#                                        CITY_ID              CITY  ZIP_CODE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  54178039  Levallois-Perret   92300.0
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d  54178039  Levallois-Perret   92300.0
#
#                                      DEPT_CODE   PUBLICATION_START_DATE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe        92  2017-03-22T04:07:56.095
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d        92  2018-09-18T11:04:44.461
#
#                                       PUBLICATION_END_DATE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe                   NaN
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d                   NaN
#
#                                               LAST_CRAWL_DATE  \
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe  2017-04-21T18:52:35.733
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d   2019-06-06T10:08:10.89
#
#                                       LAST_PRICE_DECREASE_DATE
# ID
# 22c05930-0eb5-11e7-b53d-bbead8ba43fe                       NaN
# 8d092fa0-bb99-11e8-a7c9-852783b5a69d                2018-09-25
#
# [2 rows x 56 columns]

# %% [markdown]
# <details>
# <summary>Autre méthode</summary>
# <br>
# Avec l'accès aux credentials, nous pourrions imaginer nous connecter via l'API Google, voire nous aider d'une librairie telle que gspread.
# </details>

# %% [markdown]
# ## Analyse

# %% [markdown]
# Nous désirons nous faire une idée générale des colonnes présentes ainsi que du nombre d'entrée (2164 pour cet extrait).
#
# Nous en profitons pour faire un récapitulatif statistique permettant d'apprécier les grandes tendances.

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2164 entries, 22c05930-0eb5-11e7-b53d-bbead8ba43fe to f3ae8be0-9fcf-11e9-ab3e-47ec2b68d334
# Data columns (total 56 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   URL                         2164 non-null   object
#  1   CRAWL_SOURCE                2164 non-null   object
#  2   PROPERTY_TYPE               2164 non-null   object
#  3   NEW_BUILD                   1973 non-null   object
#  4   DESCRIPTION                 2160 non-null   object
#  5   IMAGES                      2164 non-null   object
#  6   SURFACE                     2050 non-null   float64
#  7   LAND_SURFACE                3 non-null      float64
#  8   BALCONY_SURFACE             0 non-null      float64
#  9   TERRACE_SURFACE             25 non-null     float64
#  10  ROOM_COUNT                  1835 non-null   float64
#  11  BEDROOM_COUNT               696 non-null    float64
#  12  BATHROOM_COUNT              0 non-null      float64
#  13  LUNCHROOM_COUNT             0 non-null      float64
#  14  TOILET_COUNT                0 non-null      float64
#  15  FURNISHED                   467 non-null    object
#  16  FIREPLACE                   0 non-null      float64
#  17  AIR_CONDITIONING            0 non-null      float64
#  18  GARDEN                      14 non-null     float64
#  19  SWIMMING_POOL               6 non-null      float64
#  20  BALCONY                     0 non-null      float64
#  21  TERRACE                     86 non-null     float64
#  22  CELLAR                      0 non-null      float64
#  23  PARKING                     2164 non-null   bool
#  24  PARKING_COUNT               157 non-null    float64
#  25  HEATING_TYPES               2164 non-null   object
#  26  HEATING_MODE                653 non-null    object
#  27  FLOOR                       660 non-null    float64
#  28  FLOOR_COUNT                 465 non-null    float64
#  29  CONSTRUCTION_YEAR           503 non-null    float64
#  30  ELEVATOR                    552 non-null    object
#  31  CARETAKER                   247 non-null    object
#  32  ENERGY_CONSUMPTION          0 non-null      float64
#  33  GREENHOUSE_GAS_CONSUMPTION  0 non-null      float64
#  34  MARKETING_TYPE              2164 non-null   object
#  35  PRICE                       2104 non-null   float64
#  36  PRICE_M2                    1991 non-null   float64
#  37  PRICE_EVENTS                2164 non-null   object
#  38  RENTAL_EXPENSES             441 non-null    float64
#  39  RENTAL_EXPENSES_INCLUDED    600 non-null    object
#  40  DEPOSIT                     55 non-null     float64
#  41  FEES                        94 non-null     float64
#  42  FEES_INCLUDED               511 non-null    object
#  43  EXCLUSIVE_MANDATE           2164 non-null   bool
#  44  AGENCIES_UNWANTED           201 non-null    object
#  45  OCCUPIED                    1209 non-null   object
#  46  DEALER_NAME                 2077 non-null   object
#  47  DEALER_TYPE                 2164 non-null   object
#  48  CITY_ID                     2164 non-null   int64
#  49  CITY                        2164 non-null   object
#  50  ZIP_CODE                    2163 non-null   float64
#  51  DEPT_CODE                   2164 non-null   int64
#  52  PUBLICATION_START_DATE      2164 non-null   object
#  53  PUBLICATION_END_DATE        0 non-null      float64
#  54  LAST_CRAWL_DATE             2164 non-null   object
#  55  LAST_PRICE_DECREASE_DATE    340 non-null    object
# dtypes: bool(2), float64(29), int64(2), object(23)
# memory usage: 934.1+ KB

# %%
raw_df.describe()
# Out:
#             SURFACE  LAND_SURFACE  BALCONY_SURFACE  TERRACE_SURFACE  \
# count   2050.000000      3.000000              0.0        25.000000
# mean     128.136068     30.000000              NaN        31.363600
# std      423.339898      8.660254              NaN        57.467242
# min        6.000000     25.000000              NaN         5.590000
# 25%       36.200000     25.000000              NaN        13.000000
# 50%       55.000000     25.000000              NaN        18.000000
# 75%       93.000000     32.500000              NaN        26.000000
# max    10287.000000     40.000000              NaN       300.000000
#
#         ROOM_COUNT  BEDROOM_COUNT  BATHROOM_COUNT  LUNCHROOM_COUNT  \
# count  1835.000000     696.000000             0.0              0.0
# mean      2.243597       1.847701             NaN              NaN
# std       1.715621       1.104508             NaN              NaN
# min       0.000000       1.000000             NaN              NaN
# 25%       1.000000       1.000000             NaN              NaN
# 50%       2.000000       1.000000             NaN              NaN
# 75%       3.000000       2.000000             NaN              NaN
# max      10.000000       8.000000             NaN              NaN
#
#        TOILET_COUNT  FIREPLACE  ...  GREENHOUSE_GAS_CONSUMPTION         PRICE  \
# count           0.0        0.0  ...                         0.0  2.104000e+03
# mean            NaN        NaN  ...                         NaN  4.261142e+05
# std             NaN        NaN  ...                         NaN  6.486603e+05
# min             NaN        NaN  ...                         NaN  3.300000e+01
# 25%             NaN        NaN  ...                         NaN  1.600000e+03
# 50%             NaN        NaN  ...                         NaN  2.200000e+05
# 75%             NaN        NaN  ...                         NaN  6.097500e+05
# max             NaN        NaN  ...                         NaN  6.000000e+06
#
#            PRICE_M2  RENTAL_EXPENSES       DEPOSIT          FEES     CITY_ID  \
# count   1991.000000       441.000000     55.000000     94.000000      2164.0
# mean    5483.773420       406.687347   2988.506000   1531.935957  54178039.0
# std     5384.760624      1329.451157   8071.172419   6269.065130         0.0
# min        1.780000         2.000000     70.000000     29.500000  54178039.0
# 25%       32.375000        60.000000    860.500000    378.000000  54178039.0
# 50%     7586.210000       100.000000   1350.000000    639.670000  54178039.0
# 75%    10056.750000       151.000000   2450.000000    806.700000  54178039.0
# max    89000.000000     14287.330000  60000.000000  60000.000000  54178039.0
#
#        ZIP_CODE  DEPT_CODE  PUBLICATION_END_DATE
# count    2163.0     2164.0                   0.0
# mean    92300.0       92.0                   NaN
# std         0.0        0.0                   NaN
# min     92300.0       92.0                   NaN
# 25%     92300.0       92.0                   NaN
# 50%     92300.0       92.0                   NaN
# 75%     92300.0       92.0                   NaN
# max     92300.0       92.0                   NaN
#
# [8 rows x 31 columns]

# %% [markdown]
# ## Nettoyage

# %% [markdown]
# Rendons la donnée plus lisible en éliminant les colonnes n'apportant aucun élément de comparaison probants entre deux biens immobilier, ainsi que les colonnes de lieu contenant une information similaire.
#
# Notons que nous retirons ici les images: les filigrannes et l'incertitude d'avoir des photographies similaires nous en décourage.

# %%
# Colonnes non-pertinentes à enlever
col_to_drop = ['URL', 'CRAWL_SOURCE', 'CRAWL_SOURCE', 'IMAGES', 'PRICE_EVENTS', 'FEES', 'FEES_INCLUDED', 'DEALER_NAME',
 'DEALER_TYPE', 'CITY_ID', 'CITY', 'DEPT_CODE', 'PUBLICATION_START_DATE', 'PUBLICATION_END_DATE',
 'LAST_CRAWL_DATE', 'LAST_PRICE_DECREASE_DATE']

df = raw_df.drop(col_to_drop, axis=1)

# %% [markdown]
# Toujours en vue d'alléger le processus, nous enlevons les colonnes n'ayant pas  ou peu d'informations.

# %%
# On retire les colonnes vides ou contenant peu déléments comparables
df.dropna(axis=1, thresh=0.1*len(df), inplace=True)
df.sort_index(axis=1, inplace=True)
df.count()
# Out:
# BEDROOM_COUNT                696
# CARETAKER                    247
# CONSTRUCTION_YEAR            503
# DESCRIPTION                 2160
# ELEVATOR                     552
# EXCLUSIVE_MANDATE           2164
# FLOOR                        660
# FLOOR_COUNT                  465
# FURNISHED                    467
# HEATING_MODE                 653
# HEATING_TYPES               2164
# MARKETING_TYPE              2164
# NEW_BUILD                   1973
# OCCUPIED                    1209
# PARKING                     2164
# PRICE                       2104
# PRICE_M2                    1991
# PROPERTY_TYPE               2164
# RENTAL_EXPENSES              441
# RENTAL_EXPENSES_INCLUDED     600
# ROOM_COUNT                  1835
# SURFACE                     2050
# ZIP_CODE                    2163
# dtype: int64

# %% [markdown]
# ## Regroupement

# %% [markdown]
# Nous pourrions éléminer l'ensemble des entrées n'ayant aucun doublon "remarquables", telle que la surface, mais décidons ici de traiter l'ensemble de la table d'un seul coup, étant donné le nombre limité d'enregistrements.
#
# Pour ce faire, plusieurs méthodologies seraient envisageables (nlp, etc.). Nous imaginons ici un besoin de résultat rapide et allons comparer les similitudes entre les lignes à l'aide de leur distance euclidienne.
#
# A noter qu'il nous faudrait imaginer entrainer le modèle sur un dataset dont les regroupements sont connus pour estimer sa fiabilité. Nous serons donc conservateurs, en privilégiant la précision sur le recall, avec un seuil de ressemblance de 70%.

# %%
from scipy.spatial.distance import pdist, squareform

# Création d'une matrice de comparaison des offres une à une
comp_1 = pd.DataFrame(
    1 - squareform(pdist(df, lambda u,v: (u != v).mean())),
    columns = df.index.values,
    index = df.index.values
)

# %%
# Nous créons une table de comparaison deux à deux des biens, mis en lien avec le score
comp_2 = comp_1.unstack().to_frame().reset_index().set_axis(['Bien A', 'Bien B', 'Score'], axis=1)

# Conditions sur le score pour être considéré comme dupliqué
comp_2 = comp_2[(comp_2['Score'] < 1) & (comp_2['Score'] > 0.7)]

# On retire toutes les entrées similaires (ex: A-B ou B-A)
comp_2['check_string'] = comp_2.apply(lambda row: ''.join(sorted([row['Bien A'], row['Bien B']])), axis=1)
comp_2 = comp_2.drop_duplicates('check_string').drop(['check_string'], axis=1)

# %% [markdown]
# Nous obtenons ci-dessous en résultat des couples de biens semblant similaires.

# %%
comp_2.sort_values(by='Bien A', ascending=False, axis=0)
# Out:
#                                        Bien A  \
# 249330   ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0
# 614443   fe9c3190-a850-11e9-aa5e-8b8909b4f047
# 2470775  fdc18e60-c7c7-11e8-a690-852783b5a69d
# 2470320  fdc18e60-c7c7-11e8-a690-852783b5a69d
# 2535540  fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80
# ...                                       ...
# 2475555  04cb8da0-78db-11e8-9715-3760d659752c
# 2182353  03699de0-a8ae-11e9-aa5e-8b8909b4f047
# 2183414  03699de0-a8ae-11e9-aa5e-8b8909b4f047
# 2751757  035e9270-afe2-11e9-81e9-5f24299f2ef3
# 4323540  0312e330-8971-11e9-8a42-a16638394d93
#
#                                        Bien B     Score
# 249330   99efb670-8188-11e9-a3ea-ffe50e0986b0  0.782609
# 614443   053730e0-ae5f-11e9-9fab-c3006e339e11  0.739130
# 2470775  c0a126e0-c7a8-11e8-a690-852783b5a69d  0.739130
# 2470320  08c98a90-0596-11e9-8321-1350c9447565  0.739130
# 2535540  6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f  0.782609
# ...                                       ...       ...
# 2475555  dbe80e20-f294-11e8-9c01-a577da129fbb  0.739130
# 2182353  6e1d4990-a8de-11e9-96d9-fb3253f8fc6c  0.739130
# 2183414  5f7022f0-a9b5-11e9-aa5e-8b8909b4f047  0.782609
# 2751757  c150f140-afcb-11e9-81e9-5f24299f2ef3  0.782609
# 4323540  21589ec0-896c-11e9-a7f2-f5443208fc78  0.739130
#
# [162 rows x 3 columns]

# %% [markdown]
# Nous allons regrouper ces biens à l'aide d'une nouvelle colonne 'ID DUPLICATES', et d'un identifiant commun.
# Ainsi la table finale se voudra directement exploitable par l'utilisateur, qu'il y ait regroupement ou non.
#
# Tout d'abord, créons un dictionnaire reliant chacun de ces biens à un identifiants de regroupement.

# %%
duplicated_col = {}
counter = 0

# Création d'un dictionnaire d'id de regroupements sous l forme {index: batch de regroupement}
for i, r in comp_2.sort_values(by='Bien A').iterrows():
    if not r['Bien A'] in duplicated_col:
        counter += 1
        duplicated_col[r['Bien A']] = counter
        duplicated_col[r['Bien B']] = counter
    else:
        duplicated_col[r['Bien B']] = duplicated_col[r['Bien A']]

# %% [markdown]
# Nous réassignons alors ces identifiants à la nouvelle colonnes, puis nettoyons chaque regroupement pour s'assurer qu'ils contiennent des enregistrements similaires vis-à-vis des métrics principales.
#
# A noter qu'une de nos hypothèses part du principe que différents agents peuvent parfois ne pas remplir de manière exhaustive certaines informations (nombre de salle de bain, etc), alors que d'autres paraissent immuables (surface, étage en cas d'appartements situés dans le même immeuble, etc).

# %%
final_df = df
final_df['ID DUPLICATES'] = np.nan
final_df['ID DUPLICATES'] = final_df['ID DUPLICATES'].astype('Int64')

# On assigne les id de regroupement à une nouvelle colonne 'ID DUPLICATES'
for k, v in duplicated_col.items():
    final_df.loc[k, 'ID DUPLICATES'] = v
    
# On consolide les regroupements en vérifiant les grandes métrics immobilières pour chaque
checked_col = ['CONSTRUCTION_YEAR', 'FLOOR_COUNT', 'SURFACE', 'PRICE_M2', 'PROPERTY_TYPE', 'SURFACE']

# Vérification de l'existente d'au moins un duplicat par regroupement, correction dans le cas contraire
for i, r in final_df.iterrows():
    if type(r['ID DUPLICATES']) == int:
        duplicates = final_df.loc[final_df['ID DUPLICATES'] == r['ID DUPLICATES']].duplicated(checked_col)
        for j, v in duplicates.iloc[1:].to_frame().iterrows():
            if not v[0]:
                final_df.loc[j, 'ID DUPLICATES'] = np.nan

# %% [markdown]
# Nous obtenons alors la table finale, prête au partage via son intégration au sein d'une API, contenant l'ensemble des biens, dont les ceux dupliqués (dernière colonne).

# %%
final_df.sort_values(['ID DUPLICATES'], ascending=False).head(10)
# Out:
#                                       BEDROOM_COUNT CARETAKER  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0            1.0       NaN
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0            1.0       NaN
# fe9c3190-a850-11e9-aa5e-8b8909b4f047            2.0     False
# fdc18e60-c7c7-11e8-a690-852783b5a69d            1.0     False
# c0a126e0-c7a8-11e8-a690-852783b5a69d            1.0       NaN
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80            1.0       NaN
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f            1.0     False
# fa2296f0-ff44-11e8-a522-11b900e7785d            1.0       NaN
# 72a8d9c0-ff38-11e8-84f5-374944e977fb            1.0     False
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047            NaN       NaN
#
#                                       CONSTRUCTION_YEAR  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0             1950.0
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0             1950.0
# fe9c3190-a850-11e9-aa5e-8b8909b4f047             2001.0
# fdc18e60-c7c7-11e8-a690-852783b5a69d             2012.0
# c0a126e0-c7a8-11e8-a690-852783b5a69d             2012.0
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80             1990.0
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f             1990.0
# fa2296f0-ff44-11e8-a522-11b900e7785d             1930.0
# 72a8d9c0-ff38-11e8-84f5-374944e977fb             1930.0
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047                NaN
#
#                                                                             DESCRIPTION  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0  BOULEVARD BINEAU, dans un bel immeuble ancien ...
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0  BOULEVARD BINEAU, dans un bel immeuble ancien ...
# fe9c3190-a850-11e9-aa5e-8b8909b4f047  Dans un immeuble très récent, à côté du Parc d...
# fdc18e60-c7c7-11e8-a690-852783b5a69d  Dans une copropriété de grand standing de 2012...
# c0a126e0-c7a8-11e8-a690-852783b5a69d  Dans une copropriété de grand standing de 2012...
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80  LEVALLOIS | PONT DE LEVALLOIS | 2 PIÈCES Appar...
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f  LEVALLOIS | PONT DE LEVALLOIS | 2 PIECES Appar...
# fa2296f0-ff44-11e8-a522-11b900e7785d  Levallois / Victor Hugo - Spécial Investisseur...
# 72a8d9c0-ff38-11e8-84f5-374944e977fb  Levallois / Victor Hugo - Spécial Investisseur...
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047  A 2 pas de la Gare Clichy Levallois, et proche...
#
#                                      ELEVATOR  EXCLUSIVE_MANDATE  FLOOR  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0     True              False    2.0
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0     True              False    2.0
# fe9c3190-a850-11e9-aa5e-8b8909b4f047     True              False    2.0
# fdc18e60-c7c7-11e8-a690-852783b5a69d     True              False    NaN
# c0a126e0-c7a8-11e8-a690-852783b5a69d     True              False    NaN
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80     True              False    4.0
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f     True              False    4.0
# fa2296f0-ff44-11e8-a522-11b900e7785d    False              False    3.0
# 72a8d9c0-ff38-11e8-84f5-374944e977fb    False              False    3.0
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047     True              False    6.0
#
#                                       FLOOR_COUNT FURNISHED HEATING_MODE  ...  \
# ID                                                                        ...
# 99efb670-8188-11e9-a3ea-ffe50e0986b0          NaN     False          NaN  ...
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0          NaN     False          NaN  ...
# fe9c3190-a850-11e9-aa5e-8b8909b4f047          6.0       NaN   INDIVIDUAL  ...
# fdc18e60-c7c7-11e8-a690-852783b5a69d          5.0       NaN   COLLECTIVE  ...
# c0a126e0-c7a8-11e8-a690-852783b5a69d          5.0       NaN   COLLECTIVE  ...
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80          5.0       NaN   INDIVIDUAL  ...
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f          5.0       NaN   INDIVIDUAL  ...
# fa2296f0-ff44-11e8-a522-11b900e7785d          6.0       NaN   INDIVIDUAL  ...
# 72a8d9c0-ff38-11e8-84f5-374944e977fb          6.0       NaN   INDIVIDUAL  ...
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047          NaN      True   COLLECTIVE  ...
#
#                                      PARKING     PRICE  PRICE_M2  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0   False    1430.0     26.05
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0   False    1430.0     26.05
# fe9c3190-a850-11e9-aa5e-8b8909b4f047    True  830000.0  11527.78
# fdc18e60-c7c7-11e8-a690-852783b5a69d   False  449000.0   9212.15
# c0a126e0-c7a8-11e8-a690-852783b5a69d   False  449000.0   9212.15
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80   False  520000.0  10400.00
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f   False  520000.0  10400.00
# fa2296f0-ff44-11e8-a522-11b900e7785d   False  265000.0   7794.12
# 72a8d9c0-ff38-11e8-84f5-374944e977fb   False  265000.0   7794.12
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047   False    1004.0     26.42
#
#                                      PROPERTY_TYPE  RENTAL_EXPENSES  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0     APARTMENT             80.0
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0     APARTMENT             80.0
# fe9c3190-a850-11e9-aa5e-8b8909b4f047     APARTMENT              NaN
# fdc18e60-c7c7-11e8-a690-852783b5a69d     APARTMENT              NaN
# c0a126e0-c7a8-11e8-a690-852783b5a69d     APARTMENT              NaN
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80     APARTMENT              NaN
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f     APARTMENT              NaN
# fa2296f0-ff44-11e8-a522-11b900e7785d     APARTMENT              NaN
# 72a8d9c0-ff38-11e8-84f5-374944e977fb     APARTMENT              NaN
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047     APARTMENT            100.0
#
#                                       RENTAL_EXPENSES_INCLUDED  ROOM_COUNT  \
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0                      True         2.0
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0                      True         2.0
# fe9c3190-a850-11e9-aa5e-8b8909b4f047                       NaN         3.0
# fdc18e60-c7c7-11e8-a690-852783b5a69d                       NaN         2.0
# c0a126e0-c7a8-11e8-a690-852783b5a69d                       NaN         2.0
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80                       NaN         2.0
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f                       NaN         2.0
# fa2296f0-ff44-11e8-a522-11b900e7785d                       NaN         1.0
# 72a8d9c0-ff38-11e8-84f5-374944e977fb                       NaN         1.0
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047                      True         2.0
#
#                                      SURFACE  ZIP_CODE ID DUPLICATES
# ID
# 99efb670-8188-11e9-a3ea-ffe50e0986b0   54.90   92300.0           112
# ffc30ed0-81c3-11e9-a3ea-ffe50e0986b0   54.90   92300.0           112
# fe9c3190-a850-11e9-aa5e-8b8909b4f047   72.00   92300.0           111
# fdc18e60-c7c7-11e8-a690-852783b5a69d   48.74   92300.0           110
# c0a126e0-c7a8-11e8-a690-852783b5a69d   48.74   92300.0           110
# fd1526b0-d6a1-11e7-9a1c-0fee3e6b9b80   50.00   92300.0           109
# 6c8c2c00-e084-11e7-a8f5-5d2fe6a4377f   50.00   92300.0           109
# fa2296f0-ff44-11e8-a522-11b900e7785d   34.00   92300.0           108
# 72a8d9c0-ff38-11e8-84f5-374944e977fb   34.00   92300.0           108
# 3bd70ba0-a60f-11e9-aa5e-8b8909b4f047   38.00   92300.0           107
#
# [10 rows x 24 columns]

# %% [markdown]
# ## Conclusion

# %% [markdown]
# Il semble que les données internes à Yanport permettent de visualiser le regroupement grâce aux douze derniers caractères de l'ID. Ces données ne sont pas supposées exister lors de l'extraction, nous n'avons donc pas creusé en ce sens.
#
# A l'aide de ce modèle, nous avons trouvé 104 biens en doublons, pour 208 entrées.

# %%
print(final_df['ID DUPLICATES'].count())
print(len(final_df['ID DUPLICATES'].unique()))
# Out:
# 208
# 104

# %% [markdown]
# ## Outro

# %% [markdown]
# Il est bien sûr toujours possible d'aller plus loin, par exemple :
# - Vérifier la précision du modèle sur un dataset connu
# - Pousser la recherche des colonnes pertinentes
# - Mettre en place d'autres modèles
# - comparer les description
# - Charger le tout au sein d'un ETL ou d'un workflow
